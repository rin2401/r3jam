# %% [markdown]
# # Weak Type

# %%
def solve(text):
    hand = None
    count = 0
    for s in text:
        if s != "F" and hand != s:
            hand = s
            count += 1
    
    if count > 0:
        count -= 1 

    return count


test_path = "weak_typing_chapter_1_sample"
test_path = "weak_typing_chapter_1"

with open(f"{test_path}_input.txt", encoding="utf-8") as f:
    texts = [l.strip() for l in f][2::2]
    
with open(f"{test_path}_output.txt", "w", encoding="utf-8") as f:
    for i, text in enumerate(texts):
        print(f"Case #{i+1}:", solve(text))
        f.write(f"Case #{i+1}: {solve(text)}\n")
# Out:
# Case #1: 286
# Case #2: 369
# Case #3: 37
# Case #4: 54
# Case #5: 1
# Case #6: 264
# Case #7: 140
# Case #8: 0
# Case #9: 62
# Case #10: 6
# Case #11: 58
# Case #12: 0
# Case #13: 10
# Case #14: 465
# Case #15: 1
# Case #16: 40
# Case #17: 76
# Case #18: 385
# Case #19: 799999
# Case #20: 66
# Case #21: 32
# Case #22: 115
# Case #23: 192
# Case #24: 83
# Case #25: 153
# Case #26: 156
# Case #27: 130
# Case #28: 132
# Case #29: 0
# Case #30: 9
# Case #31: 36
# Case #32: 141
# Case #33: 2
# Case #34: 0
# Case #35: 0
# Case #36: 94
# Case #37: 153
# Case #38: 0
# Case #39: 24
# Case #40: 164
# Case #41: 0
# Case #42: 338
# Case #43: 361
# Case #44: 178
# Case #45: 55
# Case #46: 18
# Case #47: 0
# Case #48: 15
# Case #49: 341
# Case #50: 0
# Case #51: 231914
# Case #52: 331
# Case #53: 71
# Case #54: 70
# Case #55: 242
# Case #56: 6
# Case #57: 226
# Case #58: 2
# Case #59: 407
# Case #60: 161
# Case #61: 54
# Case #62: 0
# Case #63: 8790
# Case #64: 58
# Case #65: 0
# Case #66: 275
# Case #67: 34
# Case #68: 215
# Case #69: 9
# Case #70: 89
# Case #71: 0
# Case #72: 166
# Case #73: 108
# Case #74: 26
# Case #75: 0
# Case #76: 130
# Case #77: 158
# Case #78: 217
# Case #79: 142
# Case #80: 0
